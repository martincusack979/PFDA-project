# %% [markdown]
# # Programming for Data Analysis project

# %% [markdown]
# #### G00239124 Martin Cusack
#
# In this project, I will synthesise a dataset using various packages within Python.  I will investigate the properties of the resulting data to gain insights into the real-world phenomenon of world population growth.

# %% [markdown]
# ![world.png](attachment:world.png)

# %% [markdown]
# ## Introduction
#
# On July 11 2022, Reuters carried a [report](https://www.reuters.com/world/india/india-surpass-china-most-populous-country-2023-un-report-2022-07-11/) on a new United Nations study which revealed that India was due to surpass China as the most populous country on our planet at some point in th year 2023.  I have always been interested in the phenomenon of population growth (as well as fluctuating fertility rates within individual countries) and what this might tell us about the future of our societies.
#
# The subject of population growth seems particularly relevant at the present moment, when there is so much anxiety about the damage which man-made processes are wreaking on our environment and the resulting effects on climate change.  Does the inevitable increase in consumption of natural resources brought about by population growth present an equal threat to our environment as that of industrial pollution and the burning of fossil fuels?
#
# I wanted to explore a [dataset](https://www.kaggle.com/code/hasibalmuzdadid/world-population-analysis/data?select=world_population.csv) with figures on population growth over recent decadees in order to take a closer look at this phenomenon and see what insights could be gleaned.  I sourced a dataset on world population growth from the popular data science website Kaggle.

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv (r"C:\Users\cusac\OneDrive\Desktop\world_population.csv")

# %%
df.shape
# Out:
# (234, 14)

# %%
df.head(7)
# Out:
#    Rank         Country           Capital      Continent  2022 Population  \
# 0    36     Afghanistan             Kabul           Asia         41128771
# 1   138         Albania            Tirana         Europe          2842321
# 2    34         Algeria           Algiers         Africa         44903225
# 3   213  American Samoa         Pago Pago        Oceania            44273
# 4   203         Andorra  Andorra la Vella         Europe            79824
# 5    42          Angola            Luanda         Africa         35588987
# 6   224        Anguilla        The Valley  North America            15857
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# ...

# %%
df.describe()
# Out:
#              Rank  2020 Population  2010 Population  2000 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.350107e+07     2.984524e+07     2.626947e+07
# std     67.694165     1.355899e+08     1.242185e+08     1.116982e+08
# min      1.000000     5.200000e+02     5.960000e+02     6.510000e+02
# 25%     59.250000     4.152845e+05     3.931490e+05     3.272420e+05
# 50%    117.500000     5.493074e+06     4.942770e+06     4.292907e+06
# 75%    175.750000     2.144798e+07     1.915957e+07     1.576230e+07
# max    234.000000     1.424930e+09     1.348191e+09     1.264099e+09
#
#        1990 Population  1980 Population  1970 Population    Area (km²)  \
# count     2.340000e+02     2.340000e+02     2.340000e+02  2.340000e+02
# mean      2.271022e+07     1.898462e+07     1.578691e+07  5.814494e+05
# std       9.783217e+07     8.178519e+07     6.779509e+07  1.761841e+06
# ...

# %%
#check for null values
df.isnull().sum()
# Out:
# Rank                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %% [markdown]
# ### Null Values
#
# There are no null values in the data set.

# %%
# get rid of extraneous columns to make analysis easier
df.drop(columns=["Capital","2022 Population","2015 Population"])
# Out:
#                Country Continent  2020 Population  2010 Population  \
# 0          Afghanistan      Asia         38972230         28189672
# 1              Albania    Europe          2866849          2913399
# 2              Algeria    Africa         43451666         35856344
# 3       American Samoa   Oceania            46189            54849
# 4              Andorra    Europe            77700            71519
# ..                 ...       ...              ...              ...
# 229  Wallis and Futuna   Oceania            11655            13142
# 230     Western Sahara    Africa           556048           413296
# 231              Yemen      Asia         32284046         24743946
# 232             Zambia    Africa         18927715         13792086
# 233           Zimbabwe    Africa         15669666         12839771
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 0           19542982         10694796         12486631         10752971
# ...

# %%
# show six most populous nations
df_pop = df.sort_values("2020 Population", ascending = False)
df_pop = df_pop.drop(columns=["Capital","2022 Population","2015 Population"])
df_pop.head(6)
# Out:
#      Rank        Country      Continent  2020 Population  2010 Population  \
# 41      1          China           Asia       1424929781       1348191368
# 92      2          India           Asia       1396387127       1240613620
# 221     3  United States  North America        335942003        311182845
# 93      4      Indonesia           Asia        271857970        244016173
# 156     5       Pakistan           Asia        227196741        194454498
# 27      7         Brazil  South America        213196304        196353492
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 41        1264099069       1153704252        982372466        822534450
# 92        1059633675        870452165        696828385        557501301
# 221        282398554        248083732        223140018        200328340
# 93         214072421        182159874        148177096        115228394
# 156        154369924        115414069         80624057         59290872
# ...

# %% [markdown]
# ### Plotting with Matplotlib
# I used the plotting function in the Matplotlib package to gain a perspective on some key aspects of the information in my chosen data set. Firstly, I created a simple bar chart of the six most populous countries in the world, with country names on the x-axis and populations expressed in terms of billions on the y-axis. The main insight to take from the resulting visualistaion is that the population figures for China and India far outstrip all other countries in the world, being three times greater than the third largest country in population, the United States. Since the fourth and fifth most populous countries are Pakistan and Indonesia, this shows us that the vast majority of the world's population is contained within the continent of Asia.

# %%
#import matplotlib
import matplotlib.pyplot as plt

# %%
# Create bar chart of the six most populous countries
Country = ['China','India','USA','Indonesia','Pakistan', 'Brazil']
Populations = [1424929781,1396387127,335942003,271857970,227196741, 213196304]
plt.bar(Country, Populations)
plt.title('Most populous countries')
plt.xlabel('Country')
plt.ylabel('Population')
plt.show()

# %%
#create data frame of top six most populous countries
df_topSix = df_pop.head(6)
df_topSix
# Out:
#      Rank        Country      Continent  2020 Population  2010 Population  \
# 41      1          China           Asia       1424929781       1348191368
# 92      2          India           Asia       1396387127       1240613620
# 221     3  United States  North America        335942003        311182845
# 93      4      Indonesia           Asia        271857970        244016173
# 156     5       Pakistan           Asia        227196741        194454498
# 27      7         Brazil  South America        213196304        196353492
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 41        1264099069       1153704252        982372466        822534450
# 92        1059633675        870452165        696828385        557501301
# 221        282398554        248083732        223140018        200328340
# 93         214072421        182159874        148177096        115228394
# 156        154369924        115414069         80624057         59290872
# ...

# %% [markdown]
# ### Visualising data with Seaborn
# At this point, I wanted to visualise the rate of population of the world's six most populous countries since 1970 using the lineplot tool within the Seaborn package.

# %%
# import seaborn
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# create arrays for Years and Populations
Years = np.array(["1970", "1980", "1990", "2000", "2010", "2020"])
Population_in_billions = np.array([0.8, 0.9, 1.1, 1.2, 1.3, 1.4])

# convert to pandas dataframe
d = {"Years": Years, "Population_in_billions": Population_in_billions}
rate_increase = pd.DataFrame(d)

# use seaborn to create lineplot
sns.set(style='darkgrid')
sns.lineplot(x="Years", y="Population_in_billions", data = rate_increase)
plt.title("China - Population increase by decade")
plt.show()

# %% [markdown]
# ### China - Population increase by decade
# As we can see from the above visualisation, China's population almost doubled from the years 1970 to 2020; an extraordinary rate of increase, with a particularly steep rise during the 1980s.

# %%
# create arrays for Years and Populations
Years = np.array(["1970", "1980", "1990", "2000", "2010", "2020"])
Population_in_billions = np.array([0.5, 0.6, 0.8, 1.0, 1.2, 1.3])

# convert to pandas dataframe
d = {"Years": Years, "Population_in_billions": Population_in_billions}
rate_increase = pd.DataFrame(d)

# use seaborn to create lineplot
sns.set(style='darkgrid')
sns.lineplot(x="Years", y="Population_in_billions", data = rate_increase)
plt.title("India - Population increase by decade")
plt.show()

# %% [markdown]
# ### India - Population increase by decade
# Since 1970, India's population has increased even more dramatically than that of China's - almost tripling in size over five decades, with a clear boom in growth rate between 1980 and 2010.

# %%
# create arrays for Years and Populations
Years = np.array(["1970", "1980", "1990", "2000", "2010", "2020"])
Population_in_millions = np.array([200, 223, 248, 282, 311, 335])

# convert to pandas dataframe
d = {"Years": Years, "Population_in_millions": Population_in_millions}
rate_increase = pd.DataFrame(d)

# use seaborn to create lineplot
sns.set(style='darkgrid')
sns.lineplot(x="Years", y="Population_in_millions", data = rate_increase)
plt.title("USA - Population increase by decade")
plt.show()

# %% [markdown]
# ### USA - Population increase by decade
# As we can see from this lineplot, USA's population grew at a steady rate from 1970 to 1990, before sharply increasing between 1990 and 2000.  The population is now almost one and a half times larger than in 1970, a remarkable rise but showing a slightly less vertiginous growth rate than India's and China's.

# %%
# create arrays for Years and Populations
Years = np.array(["1970", "1980", "1990", "2000", "2010", "2020"])
Population_in_millions = np.array([115, 148, 182, 214, 244, 271])

# convert to pandas dataframe
d = {"Years": Years, "Population_in_millions": Population_in_millions}
rate_increase = pd.DataFrame(d)

# use seaborn to create lineplot
sns.set(style='darkgrid')
sns.lineplot(x="Years", y="Population_in_millions", data = rate_increase)
plt.title("Indonesia - Population increase by decade")
plt.show()

# %% [markdown]
# ### Indonesia - Population increase by decade
# The lineplot for Indonesia between 1970 and 2020 is almost a straight diagonal line, demonstrating a notable consistency in the populations'steady growth rate over the span of 50 years.

# %%
# create arrays for Years and Populations
Years = np.array(["1970", "1980", "1990", "2000", "2010", "2020"])
Population_in_millions = np.array([59, 80, 115, 154, 194, 227])

# convert to pandas dataframe
d = {"Years": Years, "Population_in_millions": Population_in_millions}
rate_increase = pd.DataFrame(d)

# use seaborn to create lineplot
sns.set(style='darkgrid')
sns.lineplot(x="Years", y="Population_in_millions", data = rate_increase)
plt.title("Pakistan - Population increase by decade")
plt.show()

# %% [markdown]
# ### Pakistan - Population increase by decade
# As we can see from this visualisation, Pakistan's population grew steadily from 1970 to 1980, and then rose sharply between the years 1980 and 2010 in a very similar manner to its neighbour, India. (see above)

# %%
# create arrays for Years and Populations
Years = np.array(["1970", "1980", "1990", "2000", "2010", "2020"])
Population_in_millions = np.array([96, 122, 150, 175, 196, 213])

# convert to pandas dataframe
d = {"Years": Years, "Population_in_millions": Population_in_millions}
rate_increase = pd.DataFrame(d)

# use seaborn to create lineplot
sns.set(style='darkgrid')
sns.lineplot(x="Years", y="Population_in_millions", data = rate_increase)
plt.title("Brazil - Population increase by decade")
plt.show()

# %% [markdown]
# ### Brazil - Population increase by decade
# It's obvious from this lineplot that Brazil's population, despite rising steadily from 1970 to 2000, has tapered off somewhat over the last twenty years, while still clearly on the increase.

# %%
# create bar chart displaying growth rate of top 6 countries as discrete values; use plt.ylim for y axis values
import matplotlib.pyplot as plt
Country = ['China','India','USA','Indonesia','Pakistan', 'Brazil']
Growth_Rate = [1, 1.0068, 1.0038, 1.0064, 1.0191, 1.0046]
plt.bar(Country, Growth_Rate)
plt.title('Growth Rate of Most Populous Countries')
plt.xlabel('Country')
plt.ylabel('Growth Rate')
plt.ylim([0.995,1.02])
plt.show()

# %% [markdown]
# The above bar chart is markedly different from the barchart displaying populations of countries.  This is illuminating because growth rate is an obvious predictor for population expansion.  The bar chart confirms (as per UN report) that while China is the world's most populous country, at current rates it will soon be surpassed by India, with Pakistan's remarkable growth rate suggesting that its population will rapidly increase over the coming decades.

# %% [markdown]
# ## Synthesising a Growth Rate data set
#
# Since I've identified that Growth Rate is perhaps the most significant variable in this data set, I wanted to investigate the growth rate of every country and create a visualisation of it. I will then check to see if the mean growth rate is reflected in the resulting visualisation. I will then go on to synthesise a data set based on these findings.

# %%
# find mean growth rate
df['Growth Rate'].mean()
# Out:
# 1.0095773504273502

# %%
# find standard deviation of growth rate
df['Growth Rate'].std()
# Out:
# 0.01338498453399876

# %%
# find min and max of growth rate
df['Growth Rate'].min()
# Out:
# 0.912

# %%
df['Growth Rate'].max()
# Out:
# 1.0691

# %%
# create histogram of growth rate (world population) incorporating probability density function
mu, sigma = 1.0095, 0.0133 # mean and standard deviation
count, bins, ignored = plt.hist(s, 20, density=True)   
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *   # probability density function
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.title("Histogram of World growth rates")
plt.xlabel("Growth Rate")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# The result resembles a normal distribution, with most values clustered around the mean of 1.009.  There are two outliers: the country with the lowest growth rate (Ukraine: 0.912) and the country with the highest growth rate (Moldova: 1.06)

# %% [markdown]
# ### Synthesising data
# In this section of the project I will synthesise a data set to form a comparison with my world population data set analysis.  In order to execute this I will mainly be relying on the np.random function of the numpy package to generate some random numbers.

# %%
# create numpy array of randomly generated numbers
arr_random = np.random.default_rng().uniform(low=0.92,high=1.06,size=[2000,12]) 
arr_random
# Out:
# array([[1.01284266, 0.97850398, 1.0341613 , ..., 1.04551357, 0.9719194 ,
#         1.00673916],
#        [1.04298956, 0.98019886, 1.0468175 , ..., 1.03928493, 0.93082184,
#         1.01804507],
#        [1.0362281 , 0.92294457, 1.03887168, ..., 0.97245762, 1.00906609,
#         1.03462314],
#        ...,
#        [0.96016527, 0.93275186, 0.98420627, ..., 0.96180124, 0.93014841,
#         0.9860824 ],
#        [1.0261646 , 0.93382214, 0.98986491, ..., 0.96254168, 0.9669264 ,
#         1.027012  ],
#        [0.98962398, 1.04526218, 1.05182809, ..., 1.01635725, 1.03269665,
#         1.0566204 ]])

# %%
# create data frame of randomly generated numbers based on arr_random

data_random = pd.DataFrame(arr_random, columns=["A","B","C", "D", "E", "F", "G", "H", "I", "J", "K", "L"])
data_random
# Out:
#              A         B         C         D         E         F         G  \
# 0     1.012843  0.978504  1.034161  1.050386  0.963602  1.047932  0.949280
# 1     1.042990  0.980199  1.046817  0.975755  1.030214  1.016479  0.937513
# 2     1.036228  0.922945  1.038872  0.964350  0.939133  0.984145  0.921846
# 3     1.043601  1.056324  0.991567  0.982965  0.968236  0.978051  1.029597
# 4     1.055896  0.959001  1.013131  0.977323  0.966849  1.016760  1.012947
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  1.050960  0.941932  0.979362  0.951032  1.009048  0.957302  0.957488
# 1996  0.933662  1.039300  1.036340  0.949019  1.023354  0.983736  0.992524
# 1997  0.960165  0.932752  0.984206  0.943985  1.015515  0.965057  1.048711
# 1998  1.026165  0.933822  0.989865  1.058913  1.031662  1.055358  0.975465
# 1999  0.989624  1.045262  1.051828  0.957060  0.993947  0.993469  1.059117
#
#              H         I         J         K         L
# ...

# %%
# find mean of column "K"
data_random['K'].mean()
# Out:
# 0.9906535920757027

# %%
# find standard deviation of column "K"
data_random['K'].std()
# Out:
# 0.04021062538332383

# %%
# create histogram of column "K" incorporating probability density function
mu, sigma = 0.99, 0.04 # mean and standard deviation
s = np.random.default_rng().normal(0.99, 0.04, 20000) # mean, standard deviation
count, bins, ignored = plt.hist(s, 20, density=True)   
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *           
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.title("Histogram")
plt.xlabel("Rate")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The resulting visualisation produced by this randomly generated dataset resembles a Normal or Gaussian distribution, similar to the Histogram of World Growth rates above. However as we can see it is a much tighter distribution to the absence of outliers such as Ukraine and Moldova in the Histogram of World Growth rates.

# %% [markdown]
# ### Conclusion
# By using Numpy and Pandas to generate arrays and data frames of random numbers, it is possible to synthesise a data set which closely resembles a real world data set.  The similar Normal or Gaussian distributions in the above histogram visualisations illustrate this.

# %% [markdown]
# ## REFERENCES
#
# * https://www.w3schools.com/python/pandas/pandas_dataframes.asp
#
#
# * https://pandas.pydata.org/
#
#
# * https://stackoverflow.com/questions/32752292/how-to-create-a-dataframe-of-random-integers-with-pandas
#
#
# * https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.normal.html#numpy.random.Generator.normal
#
#
# * https://stackabuse.com/generating-synthetic-data-with-numpy-and-scikit-learn/
#
#
# * https://stackoverflow.com/questions/40389018/dropping-multiple-columns-from-a-dataframe#:~:text=To%20delete%20multiple%20columns%20at,Otherwise%20remove%20it.&text=Save%20this%20answer.,-Show%20activity%20on
